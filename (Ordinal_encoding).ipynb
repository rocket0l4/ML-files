# %% [markdown]
# <a href="https://colab.research.google.com/github/rocket0l4/ML-files/blob/main/(Ordinal_encoding).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Customer.csv',usecols=[1,3,4])

# %%
df.sample(5)
# Out:
#       gender Partner Dependents
# 208   Female      No         No
# 3500  Female     Yes         No
# 3482    Male      No         No
# 4119    Male      No         No
# 1165    Male      No         No

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size = 0.2)

# %%
X_train
# Out:
#       gender Partner
# 2682    Male      No
# 199     Male      No
# 3813    Male     Yes
# 536   Female     Yes
# 2328  Female     Yes
# ...      ...     ...
# 5584    Male     Yes
# 6159  Female      No
# 2711  Female     Yes
# 2009    Male     Yes
# 7005    Male     Yes
#
# [5634 rows x 2 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# #Making of class object from ordinalEncoder

# %%
oe = OrdinalEncoder(categories=[['Male','Female'],['No','Yes']])

# %%
oe.fit(X_train)
# Out:
# OrdinalEncoder(categories=[['Male', 'Female'], ['No', 'Yes']])

# %%
X_train = oe.transform(X_train)

# %%
X_test = oe.transform(X_test)

# %%
X_train
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 1.],
#        ...,
#        [1., 1.],
#        [0., 1.],
#        [0., 1.]])

# %% [markdown]
# # for checking the attribute between two categories..

# %%
oe.categories_
# Out:
# [array(['Male', 'Female'], dtype=object), array(['No', 'Yes'], dtype=object)]

# %% [markdown]
# #for labeling the output columns, we use label encoder
# - this transfomer should be used to encode target values ie. y and not the input x.
#
# - Encode target labels with value between 0 and n_classes-1.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit(y_train)
# Out:
# LabelEncoder()

# %% [markdown]
# #it is randomly decide,which one will get the 0 or 1.
# - here we can't decide the oreder, it's not in out hand.

# %%
le.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
y_train
# Out:
# array([0, 1, 1, ..., 1, 1, 0])

# %%
df.head(15)
# Out:
#     gender Partner Dependents
# 0   Female     Yes         No
# 1     Male      No         No
# 2     Male      No         No
# 3     Male      No         No
# 4   Female      No         No
# 5   Female      No         No
# 6     Male      No        Yes
# 7   Female      No         No
# 8   Female     Yes         No
# 9     Male      No        Yes
# 10    Male     Yes        Yes
# 11    Male      No         No
# 12    Male     Yes         No
# 13    Male      No         No
# 14    Male      No         No
