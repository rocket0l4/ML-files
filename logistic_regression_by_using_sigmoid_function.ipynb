# %% [markdown]
# <a href="https://colab.research.google.com/github/rocket0l4/ML-files/blob/main/logistic_regression_by_using_sigmoid_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Generating dataset and Loading Dataset
# - class_sep is used for gap between the blue and green points.

# %%
from sklearn.datasets import make_classification
import numpy as np
X,y = make_classification(n_samples=100,n_features=2,
                          n_informative = 1,n_redundant=0,
                          n_classes=2,n_clusters_per_class=1,
                          random_state=41,hypercube=False,class_sep=15)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - camp use for colour change.

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='cool',s=100)

# %% [markdown]
# - X is used for inserting the 1 for each row in, ie it creates a column of 1's in front of the all rows.

# %%
def perceptron(X,y):
  X= np.insert(X,0,1,axis=1)
  weights = np.ones(X.shape[1])
  lr = 0.1

  for i in range(1000):
      j = np.random.randint(0,100)
      y_hat = sigmoid(np.dot(X[j],weights))
      weights = weights + lr*(y[j]-y_hat)*X[j]

  return weights[0],weights[1:]

# %% [markdown]
# #Creating sigmoid function and using it for y_hat

# %%
def sigmoid(z):
  return 1/(1+np.exp(-z))

# %%
intercept_,coef_ = perceptron(X,y)

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input+b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color ='black',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='cool',s =100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %% [markdown]
# #line drawn by usin sigmoid function but still it is not better then pre build Logistic Regeression..
