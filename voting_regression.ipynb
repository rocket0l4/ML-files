# %% [markdown]
# <a href="https://colab.research.google.com/github/rocket0l4/ML-files/blob/main/voting_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

# %% [markdown]
# #Creating a regression dataset.

# %%
X,y = make_regression(n_samples = 506,n_features=13,noise =5 ,random_state=2 )
                      #No_of rows,# No_of columns,

# %%
X
# Out:
# array([[-0.12644484,  0.06105295, -0.01036268, ...,  0.73787662,
#         -0.20695573,  1.08393363],
#        [-0.58079349, -0.42726998,  0.86542723, ...,  1.01532746,
#         -0.33551124,  0.40923638],
#        [ 0.92590802,  0.24921124, -0.07490313, ..., -0.74981056,
#         -0.34857045, -0.43419488],
#        ...,
#        [ 0.72823683, -0.75213326, -0.2822963 , ..., -0.41514197,
#         -0.14062891, -0.24608776],
#        [-0.18679814, -0.26004266,  0.80052233, ..., -1.09687159,
#          0.02067068,  0.38189696],
#        [ 1.14393404, -0.10143653,  0.53700984, ...,  0.30397088,
#          0.50659371, -0.86531342]])

# %%
y
# Out:
# array([ 160.22300233,  323.41720773, -155.12529611, -242.59795597,
#          85.00103728, -167.20083442,   86.37640344,  127.50137811,
#        -128.80172296,  159.06901205,  131.34529632, -222.25518902,
#         -43.90531071,   40.14539585,  112.85375997,   70.53107085,
#         366.83444463, -593.99697328,  -27.45567717,   35.02923861,
#         -31.48013186,  193.57181834, -122.90693932,   95.84989316,
#         300.92363191,  -76.21135073,   69.23574636,   98.5966664 ,
#         -16.43504801,  -66.55875727,   50.55296708, -126.70848851,
#          14.09700586, -248.43804736, -115.95927711, -111.48033306,
#         -39.61149488,  185.08346724, -140.50390661,  -53.91063503,
#         229.89274342,  -21.96277002, -102.51445912,  -37.0436206 ,
#          28.91132291, -252.47299906,  100.34247634, -203.47553967,
#          87.45001891,  -23.13832985, -470.86122923,  223.17268154,
#         156.15578871,   69.22427157, -104.03081927, -148.09695444,
# ...

# %%
X.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
svr = SVR()

# %%
estimators = [('lr',lr),('dt',dt),('svr',svr)]

# %%
for estimator in estimators:
  scores = cross_val_score(estimator[1],X,y,scoring='r2',cv=10)
  print(estimator[0],np.round(np.mean(scores),2))
# Out:
# lr 1.0
# dt 0.16
# svr 0.05

# %%
from sklearn.ensemble import VotingRegressor

# %%
vr = VotingRegressor(estimators)
scores = cross_val_score(vr,X,y,scoring='r2',cv=10)
print("Voting Regressor",np.round(np.mean(scores),2))
# Out:
# Voting Regressor 0.69

# %% [markdown]
# #here we are getting he cross_val score of VotingRegression in bad as compare to LogisticRegression because.
# - As we can see the cross_val score of Decison tree and Support vector is less then the 50%.
# - So due to this if we try to take the mean the mean of all the score, it give  automatically bad result as we compare to other ones.

# %%
for i in range(1,4):
  for j in range(1,4):
    for k in range(1,4):
      vr = VotingRegressor(estimators,weights=[i,j,k])
      scores = cross_val_score(vr,X,y,scoring='r2',cv=10)
      print("For i={},j={},k={}".format(i,j,k),np.round(np.mean(scores),2))
# Out:
# For i=1,j=1,k=1 0.69
# For i=1,j=1,k=2 0.59
# For i=1,j=1,k=3 0.5
# For i=1,j=2,k=1 0.63
# For i=1,j=2,k=2 0.55
# For i=1,j=2,k=3 0.52
# For i=1,j=3,k=1 0.54
# For i=1,j=3,k=2 0.52
# For i=1,j=3,k=3 0.49
# For i=2,j=1,k=1 0.83
# For i=2,j=1,k=2 0.73
# For i=2,j=1,k=3 0.66
# For i=2,j=2,k=1 0.76
# For i=2,j=2,k=2 0.69
# For i=2,j=2,k=3 0.64
# For i=2,j=3,k=1 0.69
# For i=2,j=3,k=2 0.66
# For i=2,j=3,k=3 0.61
# For i=3,j=1,k=1 0.89
# For i=3,j=1,k=2 0.82
# For i=3,j=1,k=3 0.75
# For i=3,j=2,k=1 0.83
# For i=3,j=2,k=2 0.77
# For i=3,j=2,k=3 0.72
# For i=3,j=3,k=1 0.77
# For i=3,j=3,k=2 0.73
# For i=3,j=3,k=3 0.69

# %%
dt1 = DecisionTreeRegressor(max_depth=1)
dt2 = DecisionTreeRegressor(max_depth=3)
dt3 = DecisionTreeRegressor(max_depth=5)
dt4 = DecisionTreeRegressor(max_depth=7)
dt5 = DecisionTreeRegressor(max_depth=None)

# %%
estimators = [('dt1',dt1),('dt2',dt2),('dt3',dt3),('dt4',dt4),('dt5',dt5)]

# %%
for estimator in estimators:
  scores = cross_val_score(estimator[1],X,y,scoring='r2',cv=10)
  print(estimator[0],np.round(np.mean(scores),2))
# Out:
# dt1 0.03
# dt2 0.15
# dt3 0.18
# dt4 0.2
# dt5 0.18

# %% [markdown]
# #Here using of the five different max_depth of DecsionTree Regressor and after getting the mean by using of the VotingRegressor we get the optimal output.

# %%
vr = VotingRegressor(estimators)
scores = cross_val_score(vr,X,y,scoring='r2',cv=10)
print("Voting Regressor",np.round(np.mean(scores),2))
# Out:
# Voting Regressor 0.32
