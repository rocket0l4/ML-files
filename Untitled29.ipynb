# %% [markdown]
# <a href="https://colab.research.google.com/github/rocket0l4/ML-files/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #Droping id column

# %%
df = df.iloc[:,1:]

# %% [markdown]
# #converting floweres name into 0,1,2.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df['species'] = encoder.fit_transform(df['species'])

# %%
df.head()
# Out:
#    sepal_width  petal_length  petal_width  species
# 0          3.5           1.4          0.2        0
# 1          3.0           1.4          0.2        0
# 2          3.2           1.3          0.2        0
# 3          3.1           1.5          0.2        0
# 4          3.6           1.4          0.2        0

# %% [markdown]
# #Converting into binary classification problem

# %%
df = df[df['species'] != 0][['sepal_width','petal_length','species']]

# %%
df.sample(5)
# Out:
#      sepal_width  petal_length  species
# 54           2.8           4.6        1
# 133          2.8           5.1        2
# 76           2.8           4.8        1
# 69           2.5           3.9        1
# 125          3.2           6.0        2

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['sepal_width'],df['petal_length'],c = df['species'],cmap = 'winter')

# %% [markdown]
# #Now we are doing suffeling.

# %%
df = df.sample(100)
df_train = df.iloc[:60,:].sample(10)
df_val = df.iloc[60:80,:].sample(5)
df_test = df.iloc[80:,:].sample(5)

# %% [markdown]
# #Randomly making this 10 points to our training points.(from 1 to 60 rows)

# %%
df_train
# Out:
#      sepal_width  petal_length  species
# 63           2.9           4.7        1
# 135          3.0           6.1        2
# 126          2.8           4.8        2
# 56           3.3           4.7        1
# 85           3.4           4.5        1
# 88           3.0           4.1        1
# 67           2.7           4.1        1
# 112          3.0           5.5        2
# 145          3.0           5.2        2
# 140          3.1           5.6        2

# %% [markdown]
# #Similarly making 5 random point to our validation.(from 60 to 80 rows)

# %%
df_val
# Out:
#      sepal_width  petal_length  species
# 89           2.5           4.0        1
# 73           2.8           4.7        1
# 115          3.2           5.3        2
# 54           2.8           4.6        1
# 123          2.7           4.9        2

# %% [markdown]
# #Making 5 different point for our test.(from 80 to 100 rows)

# %%
df_test
# Out:
#      sepal_width  petal_length  species
# 91           3.0           4.6        1
# 92           2.6           4.0        1
# 105          3.0           6.6        2
# 74           2.9           4.3        1
# 83           2.7           5.1        1

# %%
X_test = df_val.iloc[:,0:2].values
y_test = df_val.iloc[:,-1].values

# %% [markdown]
# #Bagging (case 1)

# %% [markdown]
# #First bootStraping part....

# %% [markdown]
# #data for  tree 1

# %%
df_bag = df_train.sample(8,replace = True)

X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]

# %%
df_bag
# Out:
#      sepal_width  petal_length  species
# 67           2.7           4.1        1
# 112          3.0           5.5        2
# 67           2.7           4.1        1
# 67           2.7           4.1        1
# 63           2.9           4.7        1
# 85           3.4           4.5        1
# 85           3.4           4.5        1
# 126          2.8           4.8        2

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from mlxtend.plotting import plot_decision_regions
from sklearn.metrics import accuracy_score

# %%
dt_bag1 = DecisionTreeClassifier()

# %%
evaluate(dt_bag1,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 1.0

# %% [markdown]
# #Data for tree 2

# %%
df_bag = df_train.sample(8,replace=True)

X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]
df_bag
# Out:
#      sepal_width  petal_length  species
# 126          2.8           4.8        2
# 112          3.0           5.5        2
# 145          3.0           5.2        2
# 140          3.1           5.6        2
# 112          3.0           5.5        2
# 63           2.9           4.7        1
# 67           2.7           4.1        1
# 140          3.1           5.6        2

# %%
dt_bag2 = DecisionTreeClassifier()
evaluate(dt_bag2,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 1.0

# %% [markdown]
# #Data for tree 3

# %%
df_bag = df_train.sample(8,replace = True)

X = df_bag.iloc[:,0:2]
y = df_bag.iloc[:,-1]
df_bag
# Out:
#      sepal_width  petal_length  species
# 135          3.0           6.1        2
# 85           3.4           4.5        1
# 88           3.0           4.1        1
# 145          3.0           5.2        2
# 135          3.0           6.1        2
# 85           3.4           4.5        1
# 88           3.0           4.1        1
# 112          3.0           5.5        2

# %%
dt_bag3 = DecisionTreeClassifier()
evaluate(dt_bag3,X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 1.0

# %%
df_test
# Out:
#      sepal_width  petal_length  species
# 91           3.0           4.6        1
# 92           2.6           4.0        1
# 105          3.0           6.6        2
# 74           2.9           4.3        1
# 83           2.7           5.1        1

# %%
print("Predict 1",dt_bag1.predict(np.array([3,6.6]).reshape(1,2)))
print("Predict 2",dt_bag2.predict(np.array([3.0,6.6]).reshape(1,2)))
print("Predict 3",dt_bag3.predict(np.array([3,6.6]).reshape(1,2)))
# Out:
# Predict 1 [2]
# Predict 2 [2]
# Predict 3 [2]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #Pasting
# - Here also we do row sampling but without replacement.

# %%
df_train
# Out:
#      sepal_width  petal_length  species
# 63           2.9           4.7        1
# 135          3.0           6.1        2
# 126          2.8           4.8        2
# 56           3.3           4.7        1
# 85           3.4           4.5        1
# 88           3.0           4.1        1
# 67           2.7           4.1        1
# 112          3.0           5.5        2
# 145          3.0           5.2        2
# 140          3.1           5.6        2

# %%
df_train.sample(8)
# Out:
#      sepal_width  petal_length  species
# 126          2.8           4.8        2
# 112          3.0           5.5        2
# 67           2.7           4.1        1
# 135          3.0           6.1        2
# 88           3.0           4.1        1
# 140          3.1           5.6        2
# 56           3.3           4.7        1
# 63           2.9           4.7        1

# %% [markdown]
# #Random Subspaces
# - Here column sampaling occure.

# %%
df1 = sns.load_dataset('iris')

# %%
df1.sample(10)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 29           4.7          3.2           1.6          0.2      setosa
# 73           6.1          2.8           4.7          1.2  versicolor
# 10           5.4          3.7           1.5          0.2      setosa
# 83           6.0          2.7           5.1          1.6  versicolor
# 76           6.8          2.8           4.8          1.4  versicolor
# 1            4.9          3.0           1.4          0.2      setosa
# 58           6.6          2.9           4.6          1.3  versicolor
# 3            4.6          3.1           1.5          0.2      setosa
# 19           5.1          3.8           1.5          0.3      setosa
# 91           6.1          3.0           4.6          1.4  versicolor

# %%
df1.sample(2,replace=True,axis=1)
# Out:
#      petal_width  sepal_length
# 0            0.2           5.1
# 1            0.2           4.9
# 2            0.2           4.7
# 3            0.2           4.6
# 4            0.2           5.0
# ..           ...           ...
# 145          2.3           6.7
# 146          1.9           6.3
# 147          2.0           6.5
# 148          2.3           6.2
# 149          1.8           5.9
#
# [150 rows x 2 columns]

# %% [markdown]
# #Random Patches
# - Both occure here Row sampling and column sampling.

# %%
df1.sample(8,replace=True).sample(2,replace=True,axis=1)
# Out:
#      sepal_width  sepal_width
# 41           2.3          2.3
# 104          3.0          3.0
# 34           3.1          3.1
# 0            3.5          3.5
# 88           3.0          3.0
# 45           3.0          3.0
# 142          2.7          2.7
# 92           2.6          2.6

# %%
def evaluate(clf,X,y):
  clf.fit(X,y)
  plot_tree(clf)
  plt.show()
  plot_decision_regions(X.values,y.values,clf=clf,legend=2)
  y_pred = clf.predict(X_test)
  print(accuracy_score(y_test,y_pred))
