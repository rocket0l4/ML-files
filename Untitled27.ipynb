# %% [markdown]
# <a href="https://colab.research.google.com/github/rocket0l4/ML-files/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polynomial Logistic Regrssion can peroform good at some point but after some point,it starts giving the bad result, in tha case other Machine learning Algorithms can perform better
# - Decision Trees
# - Random Forest
# - SVM
# etc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv('/content/ushape.csv')

# %%
df2
# Out:
#     3.159499363321345566e-02  9.869877579082642072e-01  \
# 0                   2.115098                 -0.046244
# 1                   0.882490                 -0.075756
# 2                  -0.055144                 -0.037332
# 3                   0.829545                 -0.539321
# 4                   2.112857                  0.662084
# ..                       ...                       ...
# 94                  1.699453                  0.587720
# 95                  0.218623                 -0.652521
# 96                  0.952914                 -0.419766
# 97                 -1.318500                  0.423112
# 98                 -1.296818                  0.184147
#
#     0.000000000000000000e+00
# 0                        1.0
# 1                        0.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
# ..                       ...
# 94                       1.0
# 95                       1.0
# 96                       1.0
# ...

# %% [markdown]
# #code for changing the column name.

# %%
df = df2.rename(columns={'3.159499363321345566e-02':'X','9.869877579082642072e-01':'Y','0.000000000000000000e+00':'class'})

# %%
df
# Out:
#            X         Y  class
# 0   2.115098 -0.046244    1.0
# 1   0.882490 -0.075756    0.0
# 2  -0.055144 -0.037332    1.0
# 3   0.829545 -0.539321    1.0
# 4   2.112857  0.662084    1.0
# ..       ...       ...    ...
# 94  1.699453  0.587720    1.0
# 95  0.218623 -0.652521    1.0
# 96  0.952914 -0.419766    1.0
# 97 -1.318500  0.423112    0.0
# 98 -1.296818  0.184147    0.0
#
# [99 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size =0.2,random_state = 2)

# %%
# X = df.iloc[:,0:2].values
# y = df.iloc[:,-1].values

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

# %%
clf.fit(X,y)
# Out:
# LogisticRegression()

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X,y.astype('int'),clf,legend=2)
# Out:
# <Axes: >

# %% [markdown]
# #Clearly can see, there is miss-classification occuring.
# - some blue points are in orange region.
# - some orange points are in blue region.

# %%
from sklearn.model_selection import cross_val_score
np.mean(cross_val_score(clf,X,y,scoring = 'accuracy',cv = 10))
# Out:
# 0.8300000000000001

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3)
X_trf = poly.fit_transform(X)

# %%
clf1 = LogisticRegression()
np.mean(cross_val_score(clf1,X_trf,y,scoring = 'accuracy',cv =10))
# Out:
# 0.9099999999999999

# %% [markdown]
# #Here we can clearly see the accuracy is around 90% and if we, increase our degree still it give 90%, but if we increaese degree around 11 the accuray is starts redcing ie. overfitting starts at that point
