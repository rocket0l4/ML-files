# %% [markdown]
# <a href="https://colab.research.google.com/github/rocket0l4/ML-files/blob/main/Simple_linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Salary.csv')
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
X= df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5
# 30             11.2
# 31             11.5
# 32             12.3
# 33             12.9
# 34             13.5

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     YearsExperience
# 13              4.1
# 14              4.5
# 26              9.5
# 9               3.7
# 28             10.3
# 32             12.3
# 0               1.1

# %%
y_test
# Out:
# 13     57081
# 14     61111
# 26    116969
# 9      57189
# 28    122391
# 32    128765
# 0      39343
# Name: Salary, dtype: int64

# %%
lr.predict(X_test.iloc[0:5])
# Out:
# array([ 65377.76384262,  68846.65384201, 112207.77883428,  61908.87384324,
#        119145.55883305])

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.plot(X_train,lr.predict(X_train),color= 'red')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
m = lr.coef_

# %%
b = lr.intercept_

# %%
# Y = mx + b
m * 4 +b
# Out:
# array([64510.54134278])
